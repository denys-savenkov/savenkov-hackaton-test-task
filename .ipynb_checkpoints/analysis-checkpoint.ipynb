# %%
import os
import random

import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from skimage.io import imshow

from load_data import load_data
from train import train
from build_model import build_unet
from utils import load_last_model
from predict_masks import predict_masks
# Out:
# Using TensorFlow backend.

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

SEED = 50
TEST_RATIO = 0.2   # kaggle competions have labels only in train data, so we will not use test folders for our task

# %% [markdown]
# # Load and Split Data

# %%
X, y = load_data(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_RATIO, random_state=SEED)
# Out:
# Data loading: 0/670
# Data loading: 33/670
# Data loading: 66/670
# Data loading: 99/670
# Data loading: 132/670
# Data loading: 165/670
# Data loading: 198/670
# Data loading: 231/670
# Data loading: 264/670
# Data loading: 297/670
# Data loading: 330/670
# Data loading: 363/670
# Data loading: 396/670
# Data loading: 429/670
# Data loading: 462/670
# Data loading: 495/670
# Data loading: 528/670
# Data loading: 561/670
# Data loading: 594/670
# Data loading: 627/670
# Data loading: 660/670

# %% [markdown]
# Check how data looks:

# %%
ix = random.randint(0, len(X_train))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(y_train[ix]))
plt.show()

# %% [markdown]
# # Model's prediction 'sanity' check

# %%
model = load_last_model()
y_pred = predict_masks(model, X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-de5ee2eb3ae1> in <module>
# ----> 1 model = load_last_model()
#       2 y_pred = predict_masks(model, X_test)
#
# ~\Desktop\savenkov-hackaton-test-task\utils.py in load_last_model()
#       9 def load_last_model():
#      10     list_of_files = glob.glob('model/*.h5')
# ---> 11     latest_file = max(list_of_files, key=os.path.getctime)
#      12     return load_model(latest_file, custom_objects={'dice_coef': dice_coef, 'dice_loss': dice_loss})
#
# ValueError: max() arg is an empty sequence

# %%
ix = random.randint(0, len(y_pred))
imshow(X_test[ix])
plt.show()
imshow(np.squeeze(y_test[ix]))
plt.show()
imshow(np.squeeze(y_pred[ix]))
plt.show()

# %% [markdown]
# # Model Graph

# %%
import keras
import pydot as pyd
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model

keras.utils.vis_utils.pydot = pyd
from IPython.display import HTML
style = "<style>svg{width:50% !important;height:50% !important;padding-right:100px;}</style>"
HTML(style)
# Out:
# <style>svg{width:50% !important;height:50% !important;padding-right:100px;}</style>

# %%
model = build_unet(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
plot_model(model, to_file='model.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-b950b8cba428> in <module>
# ----> 1 plot_model(model, to_file='model.png')
#
# NameError: name 'plot_model' is not defined

# %% [markdown]
# # Model train history

# %%
model = build_unet(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
history = train(model, X_train, y_train)
